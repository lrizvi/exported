# %%
import math, collections, itertools, numpy as np, pandas as pd, pint_pandas, matplotlib as mpl, matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from scipy import stats

# Global utilities
ureg    = pint_pandas.PintType.ureg
dtime_t = pd.to_timedelta(1, unit='s')
palette = plt.rcParams['axes.prop_cycle'].by_key()['color']

class dotdict(dict):
    '''dot.notation access to dictionary attributes'''
    __getattr__ = dict.get
    __setattr__ = dict.__setitem__
    __delattr__ = dict.__delitem__

def read_csv_mec(path, pint=True):
    '''Import Mecmesin data'''
    df = pd.read_csv(path, header=[0,1], skiprows=[2,3]).dropna(how='all', axis='columns')
    if pint:
        df = df.rename(columns={'Unnamed: 3_level_1' : 'dimensionless'}).pint.quantify(level=-1)
    return df

def pint2dtime(times):
    '''Converts Pint time values to Pandas deltatime.'''
    return pd.to_timedelta(
        arg  = times.pint.magnitude,
        # Strip "pint[...]" text wrapping the unit string.
        unit = str(times.dtype)[5:-1]
    )

def event_times(event_coding):
    '''Extracts event start times from Mecmesin event coding.'''
    return event_coding[event_coding.diff() == -1].index

def time2state(times, events):
    '''
    Labels each time with an associated state based on Mecmesin event start times.
    I.e. Labels each time with its Mecmesin cycle number and loading/unloading state.
    '''
    cycls      = pd.Series(pd.NA, times)
    cycls_time = pd.Series(pd.NA, times)
    for start, end, i in zip(events[::2], events[2::2], itertools.count()):
        mask = (times >= start) & (times < end)
        cycls[mask] = i
        start_aligned    = times[mask][0]
        cycls_time[mask] = (times[mask] - start_aligned) / dtime_t

    loads      = pd.Series(pd.NA, times)
    loads_time = pd.Series(pd.NA, times)
    for start, end, i in zip(events, events[1:], itertools.count()):
        mask = (times >= start) & (times < end)
        loads[mask]      = i % 2
        start_aligned    = times[mask][0]
        loads_time[mask] = (times[mask] - start_aligned) / dtime_t
    
    return cycls, cycls_time, loads, loads_time

# User inputs
data = [
    dotdict(
        data      = '00 beam fixed center CF L=20mm w=100um t=129um.csv',
        length    =  20 * ureg.mm,
        width     = 100 * ureg.um,
        thickness = 129 * ureg.um,
    ),
    dotdict(
        data      = '01 beam fixed center CF L=20mm w=100um t=129um.csv',
        length    =  20 * ureg.mm,
        width     = 100 * ureg.um,
        thickness = 129 * ureg.um,
    ),
    dotdict(
        data      = '02 beam fixed center CF L=20mm w=100um t=129um.csv',
        length    =  20 * ureg.mm,
        width     = 100 * ureg.um,
        thickness = 129 * ureg.um,
    ),
    dotdict(
        data      = '03 beam fixed center CF L=20mm w=100um t=129um.csv',
        length    =  20 * ureg.mm,
        width     = 100 * ureg.um,
        thickness = 129 * ureg.um,
    ),
    dotdict(
        data      = '04 beam fixed center CF L=20mm w=100um t=129um.csv',
        length    =  20 * ureg.mm,
        width     = 100 * ureg.um,
        thickness = 129 * ureg.um,
    ),
    dotdict(
        data      = '05 beam fixed center CF L=20mm w=100um t=129um.csv',
        length    =  20 * ureg.mm,
        width     = 100 * ureg.um,
        thickness = 129 * ureg.um,
    ),
]

for dat in data:
    # Preprocess
    dat.df       = read_csv_mec(dat.data)
    dat.df.index = pint2dtime(dat.df.Time)
    dat.events   = event_times(dat.df.Event)
    dat.df['Cycle'], dat.df['CycleTime'], dat.df['Loading'], dat.df['LoadingTime'] = time2state(dat.df.index, dat.events)
    dat.df.dropna(inplace=True)
    
    # Append flexural modulus estimate
    # dat.df['FlexMod'] = ((1/16) * (dat.df.Force / dat.df.Distance) * (dat.length**3 / dat.width / dat.thickness**3)).pint.to(ureg.GPa)

    # Create Pint-unitless data copy to suppress errors when plotting.
    # Remove unit headers from dequantify(). These cause errors with column access.
    dat.dfdq = dat.df.pint.dequantify()
    dat.dfdq.columns = dat.dfdq.columns.droplevel(-1)

# %%
# Returns Standard Error of the Mean (SEM): std / sqrt(n)
def sem(n, sum1, sum2):
    return np.sqrt((sum2 - sum1*sum1/n) / (n-1)) / np.sqrt(n)

# Checks if all elements in series are equivalent
def varies(s):
    return not (s == s.iloc[0]).all()

# Returns plottable line segment
def region_line(x0, x1, slope, intercept):
    f = lambda x: x * slope + intercept
    return [x0, x1], [f(x0), f(x1)]

# Converges on the largest linear span in a curve with least-squares regression and quasi-Monte Carlo sampling.
# Statistical modification of https://doi.org/10.1063/1.4969058
# Standard Error of the Mean (SEM) stopping rule: https://www.maxvalue.com/tip025.htm
def large_linear_region(df, r2_limit, sem_goal, qmc_kernel=stats.qmc.LatinHypercube(1)):
    assert len(df.columns) == 2
    x_unique = np.unique(df[df.columns[0]])
    n_unique = len(x_unique)
    Region   = collections.namedtuple('Region', 'i x0 x1 dx soln')
    best_fit = None
    r_sum1, r_sum2 = 0, 0
    for i in itertools.takewhile(lambda i: i < 2 or sem(i, r_sum1, r_sum2) > sem_goal, itertools.count()):
        x0, x1 = sorted(x_unique[[np.int_(qmc_kernel.random(n=2) * n_unique)]][0].squeeze())
        dx = x1 - x0 
        sel = df[(df[df.columns[0]] >= x0) & (df[df.columns[0]] <= x1)]
        if not varies(sel[sel.columns[0]]):
            continue
        soln = stats.linregress(*[v.squeeze() for v in np.hsplit(sel.values, 2)])
        r_sum1 += soln.rvalue
        r_sum2 += (r2 := soln.rvalue*soln.rvalue)
        if r2 >= r2_limit and (not best_fit or dx > best_fit.dx):
            best_fit = Region(i, x0, x1, dx, soln)
    return best_fit

def find_linear_regions(df, max_depth, **kwargs):
    if max_depth == 0 or len(df) <= 2 or not varies(df[df.columns[0]]):
        return []
    for _ in range(max_depth):
        if lin := large_linear_region(df, **kwargs):
            break
    if lin:
        return find_linear_regions(df[df[df.columns[0]] <= lin.x0], max_depth-1, **kwargs) + [lin] + find_linear_regions(df[df[df.columns[0]] >= lin.x1], max_depth-1, **kwargs)
    return []

# Find relevant linear regions
solns = []
for dat in data:
    for i in range(dat.df.Cycle.max()+1):
        for j in range(dat.df.Loading.max()+1):
            while True:
                if len(result := find_linear_regions(
                    dat.dfdq[(dat.df.Cycle==i) & (dat.df.Loading==j)][['Distance', 'Force']],
                    max_depth=2,
                    r2_limit=0.99,
                    sem_goal=0.001
                )) >= 2: # Opinionated requirement
                    solns.append(result[-1]) # Get slope of last line, which for these data most represents the model
                    print(result[-1])
                    break
print(f'Number of successful runs: {len(solns)} (100 %)')
# Out:
# Region(i=1, x0=0.7625, x1=0.8825, dx=0.12, soln=LinregressResult(slope=1.3327251825587176, intercept=-0.647064205122815, rvalue=0.9991693110136544, pvalue=0.0, stderr=0.0008922777322144152, intercept_stderr=0.0007346392620593605))
# Region(i=0, x0=0.86, x1=0.9625, dx=0.10250000000000004, soln=LinregressResult(slope=1.7274314558051944, intercept=-1.0028300742187415, rvalue=0.9988729261754147, pvalue=0.0, stderr=0.0014737996859193045, intercept_stderr=0.001344746198225589))
# Region(i=0, x0=0.8875, x1=0.96, dx=0.07250000000000001, soln=LinregressResult(slope=1.595915603691888, intercept=-0.8852827444172705, rvalue=0.9987070841606202, pvalue=0.0, stderr=0.0017121576351289032, intercept_stderr=0.001582764688285053))
# Region(i=0, x0=0.7775, x1=0.9675, dx=0.19000000000000006, soln=LinregressResult(slope=1.5344017314916982, intercept=-0.8318793616115561, rvalue=0.9974732566993776, pvalue=0.0, stderr=0.0014417038446876843, intercept_stderr=0.0012608487069188479))
# Region(i=1, x0=0.885, x1=0.9825, dx=0.09750000000000003, soln=LinregressResult(slope=1.6145031508186816, intercept=-0.9099421865424602, rvalue=0.9991344217527759, pvalue=0.0, stderr=0.0012311420156716725, intercept_stderr=0.0011502836015798404))
# Region(i=1, x0=0.815, x1=0.93, dx=0.1150000000000001, soln=LinregressResult(slope=1.4936215110328968, intercept=-0.8074718634429807, rvalue=0.9987723751779877, pvalue=0.0, stderr=0.0012498257345155879, intercept_stderr=0.0010905269381815588))
# Region(i=1, x0=0.905, x1=0.97, dx=0.06499999999999995, soln=LinregressResult(slope=1.6197995077841978, intercept=-0.920879429445118, rvalue=0.9988655407793693, pvalue=0.0, stderr=0.001722433399325431, intercept_stderr=0.0016160200527988015))
# Region(i=1, x0=0.805, x1=0.9775, dx=0.1725, soln=LinregressResult(slope=1.5891380688369994, intercept=-0.8923871144478364, rvalue=0.9976114142627827, pvalue=0.0, stderr=0.0015253078343949742, intercept_stderr=0.0013615695711174968))
# Region(i=1, x0=0.7675, x1=0.9025, dx=0.135, soln=LinregressResult(slope=1.3366436776939188, intercept=-0.6710707135236182, rvalue=0.9991649774608753, pvalue=0.0, stderr=0.0008510202335638022, intercept_stderr=0.0007116613059160447))
# Region(i=1, x0=0.905, x1=1.0075, dx=0.10250000000000004, soln=LinregressResult(slope=1.8440778561853153, intercept=-1.1350703713874781, rvalue=0.9985786264502448, pvalue=0.0, stderr=0.0017559357878024998, intercept_stderr=0.0016791356687902268))
# Region(i=1, x0=0.8725, x1=0.9325, dx=0.05999999999999994, soln=LinregressResult(slope=1.51297932046549, intercept=-0.8301604188741071, rvalue=0.9986381758723725, pvalue=0.0, stderr=0.0018109436603772422, intercept_stderr=0.001634273187280595))
# Region(i=0, x0=0.8275, x1=0.975, dx=0.14749999999999996, soln=LinregressResult(slope=1.6318123393713735, intercept=-0.9392038372912358, rvalue=0.9983100072037253, pvalue=0.0, stderr=0.001427173534293898, intercept_stderr=0.0012879306074498305))
# Region(i=0, x0=0.8325, x1=0.9525, dx=0.12, soln=LinregressResult(slope=1.4865324094691144, intercept=-0.8088253688138148, rvalue=0.999158742517401, pvalue=0.0, stderr=0.0010115716567548826, intercept_stderr=0.0009031719026983958))
# Region(i=1, x0=0.835, x1=0.985, dx=0.15000000000000002, soln=LinregressResult(slope=1.6781042760844713, intercept=-0.9842212975273863, rvalue=0.998271507991655, pvalue=0.0, stderr=0.0014657497734075781, intercept_stderr=0.0013354773108670882))
# Region(i=1, x0=0.89, x1=1.0, dx=0.10999999999999999, soln=LinregressResult(slope=1.6433779542047628, intercept=-0.9579938154621799, rvalue=0.9991574520033918, pvalue=0.0, stderr=0.001139223500678559, intercept_stderr=0.0010797213501931339))
# Region(i=0, x0=0.795, x1=0.9675, dx=0.1725, soln=LinregressResult(slope=1.5350018840490698, intercept=-0.8592392341873596, rvalue=0.9975694090950067, pvalue=0.0, stderr=0.0014765351084069028, intercept_stderr=0.0013037019455129052))
# Region(i=1, x0=0.9325, x1=0.9725, dx=0.040000000000000036, soln=LinregressResult(slope=1.6390540858159315, intercept=-0.9581339605971663, rvalue=0.9964442172019878, pvalue=0.0, stderr=0.00391682647365819, intercept_stderr=0.003731336959138029))
# Region(i=0, x0=0.8525, x1=0.995, dx=0.14249999999999996, soln=LinregressResult(slope=1.7244249313984261, intercept=-1.0349036360932926, rvalue=0.9983684165637875, pvalue=0.0, stderr=0.0014850030756224557, intercept_stderr=0.0013760606457830817))
# Region(i=0, x0=0.815, x1=0.9825, dx=0.1675000000000001, soln=LinregressResult(slope=1.484675575570015, intercept=-0.815106935089724, rvalue=0.9988556210351649, pvalue=0.0, stderr=0.0009944753941830337, intercept_stderr=0.0008947098524939929))
# Region(i=0, x0=0.7675, x1=0.9275, dx=0.16000000000000003, soln=LinregressResult(slope=1.371947070234354, intercept=-0.7245537847517536, rvalue=0.9983402333758522, pvalue=0.0, stderr=0.0011376124383679846, intercept_stderr=0.0009647127314612782))
# Region(i=0, x0=0.875, x1=0.98, dx=0.10499999999999998, soln=LinregressResult(slope=1.7761578218683058, intercept=-0.951577346730725, rvalue=0.9994121275066903, pvalue=0.0, stderr=0.0010656686952301953, intercept_stderr=0.0009884193359497998))
# Region(i=0, x0=0.855, x1=0.9625, dx=0.10750000000000004, soln=LinregressResult(slope=1.8766666216886159, intercept=-1.051450899183919, rvalue=0.9989497061898627, pvalue=0.0, stderr=0.0015034720827085501, intercept_stderr=0.0013665480444980983))
# Region(i=1, x0=0.875, x1=0.9975, dx=0.12250000000000005, soln=LinregressResult(slope=1.8075467050526288, intercept=-0.9891496946945806, rvalue=0.9994461482394909, pvalue=0.0, stderr=0.000977086678076501, intercept_stderr=0.0009152912389081781))
# Region(i=1, x0=0.7225, x1=0.94, dx=0.21749999999999992, soln=LinregressResult(slope=1.5718659674362485, intercept=-0.7849951326388613, rvalue=0.9979158859661715, pvalue=0.0, stderr=0.0012550241949790383, intercept_stderr=0.0010466154059013543))
# Region(i=5, x0=0.8275, x1=0.9925, dx=0.16500000000000004, soln=LinregressResult(slope=1.7366864623845937, intercept=-0.9270521088389286, rvalue=0.9992562150829002, pvalue=0.0, stderr=0.0009448770773385195, intercept_stderr=0.0008612818979912243))
# Region(i=1, x0=0.8375, x1=0.91, dx=0.07250000000000001, soln=LinregressResult(slope=1.7058657255293783, intercept=-0.908701127639212, rvalue=0.9989053164344214, pvalue=0.0, stderr=0.0017027500751796063, intercept_stderr=0.001488969931336191))
# Region(i=0, x0=0.88, x1=0.995, dx=0.11499999999999999, soln=LinregressResult(slope=1.8037277295789198, intercept=-0.9939476309157707, rvalue=0.999465453838169, pvalue=0.0, stderr=0.00099205379957701, intercept_stderr=0.0009305671389326572))
# Region(i=0, x0=0.795, x1=0.8975, dx=0.10249999999999992, soln=LinregressResult(slope=1.5865691321163566, intercept=-0.8085259770442841, rvalue=0.999169639967479, pvalue=0.0, stderr=0.001154366846860893, intercept_stderr=0.000976893008074388))
# Region(i=0, x0=0.91, x1=1.0, dx=0.08999999999999997, soln=LinregressResult(slope=1.8498512285596136, intercept=-1.04191136109454, rvalue=0.9992931615749269, pvalue=0.0, stderr=0.0013217386492213503, intercept_stderr=0.0012634398397874203))
# Region(i=0, x0=0.7525, x1=0.98, dx=0.22750000000000004, soln=LinregressResult(slope=1.6697264147201998, intercept=-0.8770132831303444, rvalue=0.9976855261904046, pvalue=0.0, stderr=0.0013758831358011852, intercept_stderr=0.0011955899929706885))
# Region(i=1, x0=0.8325, x1=0.965, dx=0.13249999999999995, soln=LinregressResult(slope=1.6874550334945244, intercept=-0.8937059042174503, rvalue=0.9993290685910782, pvalue=0.0, stderr=0.0009748144267122239, intercept_stderr=0.0008773482057183961))
# Region(i=0, x0=0.775, x1=0.985, dx=0.20999999999999996, soln=LinregressResult(slope=1.7267164589183863, intercept=-0.9298325709454324, rvalue=0.9973566832622927, pvalue=0.0, stderr=0.0015803939508772914, intercept_stderr=0.001393892431442545))
# Region(i=5, x0=0.8325, x1=0.9925, dx=0.16000000000000003, soln=LinregressResult(slope=1.726783614160294, intercept=-0.9311675217877396, rvalue=0.9992032015042199, pvalue=0.0, stderr=0.0009903100507495514, intercept_stderr=0.0009053314740439605))
# Region(i=1, x0=0.775, x1=0.995, dx=0.21999999999999997, soln=LinregressResult(slope=1.7493454309584295, intercept=-0.9511738618583151, rvalue=0.9972877466367673, pvalue=0.0, stderr=0.0015772594483128737, intercept_stderr=0.001400659851048631))
# Region(i=1, x0=0.8625, x1=0.975, dx=0.11249999999999993, soln=LinregressResult(slope=1.7450434514425461, intercept=-0.9525907799494725, rvalue=0.999364875737383, pvalue=0.0, stderr=0.001060139293711192, intercept_stderr=0.000975326216507196))
# Region(i=1, x0=0.855, x1=0.9975, dx=0.14250000000000007, soln=LinregressResult(slope=1.9302730183849264, intercept=-1.124771539363801, rvalue=0.998580156478697, pvalue=0.0, stderr=0.0015458669836875354, intercept_stderr=0.0014360230966203485))
# Region(i=1, x0=0.92, x1=1.0025, dx=0.0824999999999999, soln=LinregressResult(slope=1.8561687182957767, intercept=-1.061186923085991, rvalue=0.9993132110971469, pvalue=0.0, stderr=0.001365417737768335, intercept_stderr=0.0013134404008750468))
# Region(i=10, x0=0.8625, x1=1.0025, dx=0.1399999999999999, soln=LinregressResult(slope=1.9485676981343383, intercept=-1.1459675009231098, rvalue=0.9984541355195017, pvalue=0.0, stderr=0.001659992948827645, intercept_stderr=0.0015513396234319344))
# Region(i=1, x0=0.8725, x1=0.99, dx=0.11749999999999994, soln=LinregressResult(slope=1.7645473771489681, intercept=-0.9775823533434128, rvalue=0.9993983956311929, pvalue=0.0, stderr=0.0010180416697438328, intercept_stderr=0.0009485858667655973))
# Region(i=33, x0=0.8425, x1=0.995, dx=0.15249999999999997, soln=LinregressResult(slope=1.8831308867832797, intercept=-1.0872225835016527, rvalue=0.998509939780899, pvalue=0.0, stderr=0.0014967333880646849, intercept_stderr=0.001378678782739967))
# Region(i=0, x0=0.77, x1=0.8675, dx=0.09750000000000003, soln=LinregressResult(slope=1.2595746007626636, intercept=-0.6240676963265653, rvalue=0.9990279149388537, pvalue=0.0, stderr=0.0010167578599262661, intercept_stderr=0.0008329337953107729))
# Region(i=0, x0=0.875, x1=0.97, dx=0.09499999999999997, soln=LinregressResult(slope=1.687453420771242, intercept=-1.0062263616201057, rvalue=0.9983157141436675, pvalue=0.0, stderr=0.0018048689038466157, intercept_stderr=0.0016661515571829552))
# Region(i=1, x0=0.84, x1=1.0025, dx=0.16249999999999998, soln=LinregressResult(slope=1.546966080494922, intercept=-0.8761577799294886, rvalue=0.9991182249940241, pvalue=0.0, stderr=0.0009226694800000897, intercept_stderr=0.00085115982847645))
# Region(i=0, x0=0.86, x1=0.9725, dx=0.11250000000000004, soln=LinregressResult(slope=1.629596902372539, intercept=-0.9572132153244706, rvalue=0.9985150720394043, pvalue=0.0, stderr=0.001515617586096401, intercept_stderr=0.0013904062850032101))
# Region(i=1, x0=0.845, x1=0.98, dx=0.135, soln=LinregressResult(slope=1.5193995870172183, intercept=-0.8545045987270661, rvalue=0.9992558846541497, pvalue=0.0, stderr=0.0009146940902314287, intercept_stderr=0.0008346177372450152))
# Region(i=0, x0=0.875, x1=0.9725, dx=0.09750000000000003, soln=LinregressResult(slope=1.6560164723993043, intercept=-0.9832127938459128, rvalue=0.998415339746175, pvalue=0.0, stderr=0.0016959565858252154, intercept_stderr=0.0015673317620062024))
# Region(i=0, x0=0.83, x1=1.005, dx=0.17499999999999993, soln=LinregressResult(slope=1.5422210854862715, intercept=-0.8753966531154839, rvalue=0.998982667038744, pvalue=0.0, stderr=0.0009456384279848248, intercept_stderr=0.0008711879673041405))
# Region(i=1, x0=0.825, x1=0.975, dx=0.15000000000000002, soln=LinregressResult(slope=1.5477036342267831, intercept=-0.8833218332678956, rvalue=0.9985315655048628, pvalue=0.0, stderr=0.0012411330566688464, intercept_stderr=0.00111792224852301))
# Region(i=4, x0=0.85, x1=0.985, dx=0.135, soln=LinregressResult(slope=1.528305785276046, intercept=-0.865495775138548, rvalue=0.9992188318136106, pvalue=0.0, stderr=0.0009421377479161419, intercept_stderr=0.0008647188628741063))
# Region(i=1, x0=0.9025, x1=0.9925, dx=0.09000000000000008, soln=LinregressResult(slope=1.8114991756210956, intercept=-1.1314061425450614, rvalue=0.9986791928293005, pvalue=0.0, stderr=0.0017402587269953972, intercept_stderr=0.0016517241411944303))
# Region(i=0, x0=0.8875, x1=0.99, dx=0.10250000000000004, soln=LinregressResult(slope=1.5869193542460338, intercept=-0.9219100904586671, rvalue=0.9992777955423335, pvalue=0.0, stderr=0.001078262239487516, intercept_stderr=0.0010132067731699053))
# Region(i=1, x0=0.905, x1=1.005, dx=0.09999999999999987, soln=LinregressResult(slope=1.802769840596851, intercept=-1.1260684517697457, rvalue=0.998593781931349, pvalue=0.0, stderr=0.001712044380756783, intercept_stderr=0.001636387903840748))
# Region(i=1, x0=0.7825, x1=0.965, dx=0.1825, soln=LinregressResult(slope=1.4178747579973328, intercept=-0.7667391401328691, rvalue=0.9987429838462493, pvalue=0.0, stderr=0.0009546670131408725, intercept_stderr=0.0008360335283377188))
# Region(i=0, x0=0.8275, x1=0.915, dx=0.08750000000000002, soln=LinregressResult(slope=1.4326439645247384, intercept=-0.7875990487994049, rvalue=0.9988818458288048, pvalue=0.0, stderr=0.001298452274252506, intercept_stderr=0.0011323177953369938))
# Region(i=1, x0=0.825, x1=0.9575, dx=0.13250000000000006, soln=LinregressResult(slope=1.4655126026559717, intercept=-0.8117475042011886, rvalue=0.9991867468513014, pvalue=0.0, stderr=0.00093322335553709, intercept_stderr=0.0008320633952515336))
# Region(i=0, x0=0.875, x1=1.0025, dx=0.12749999999999995, soln=LinregressResult(slope=1.7185521067860086, intercept=-1.0455622643202158, rvalue=0.9982125674714597, pvalue=0.0, stderr=0.0016410575855811216, intercept_stderr=0.0015422091217584468))
# Region(i=2, x0=0.8375, x1=0.9975, dx=0.16000000000000003, soln=LinregressResult(slope=1.5430710426719314, intercept=-0.8815985107093058, rvalue=0.9989032193654048, pvalue=0.0, stderr=0.0010166166276537377, intercept_stderr=0.0009372224273703887))
# Region(i=1, x0=0.84, x1=0.9475, dx=0.10750000000000004, soln=LinregressResult(slope=1.5102373445230852, intercept=-0.8561440577236487, rvalue=0.9987775501186965, pvalue=0.0, stderr=0.001303293589727601, intercept_stderr=0.0011653961319228756))
# Region(i=1, x0=0.825, x1=0.955, dx=0.13, soln=LinregressResult(slope=1.4509751574795287, intercept=-0.7999817772851243, rvalue=0.9992019574472593, pvalue=0.0, stderr=0.0009234737513727461, intercept_stderr=0.0008221733360296594))
# Region(i=1, x0=0.7975, x1=0.9725, dx=0.17500000000000004, soln=LinregressResult(slope=1.484623628220425, intercept=-0.8307487253191183, rvalue=0.998060539217512, pvalue=0.0, stderr=0.0012665736565483188, intercept_stderr=0.0011227593168508117))
# Region(i=1, x0=0.8225, x1=0.9175, dx=0.09499999999999997, soln=LinregressResult(slope=1.7445335351186362, intercept=-0.8766622691883709, rvalue=0.99930876626096, pvalue=0.0, stderr=0.0011942638887921136, intercept_stderr=0.0010396144044073294))
# Region(i=1, x0=0.8225, x1=0.985, dx=0.16249999999999998, soln=LinregressResult(slope=1.9812329738025927, intercept=-1.09348200825627, rvalue=0.998316223825373, pvalue=0.0, stderr=0.0016405243593953299, intercept_stderr=0.001483601997242759))
# Region(i=0, x0=0.885, x1=0.9975, dx=0.11250000000000004, soln=LinregressResult(slope=1.949253686973251, intercept=-1.0699921140416206, rvalue=0.9994886948251166, pvalue=0.0, stderr=0.0010636537673920949, intercept_stderr=0.0010022563207270937))
# Region(i=1, x0=0.875, x1=0.99, dx=0.11499999999999999, soln=LinregressResult(slope=2.088855441690108, intercept=-1.2016040620522734, rvalue=0.9989404745865581, pvalue=0.0, stderr=0.0016322418613352312, intercept_stderr=0.0015228306938312461))
# Region(i=1, x0=0.8425, x1=0.95, dx=0.10749999999999993, soln=LinregressResult(slope=1.8207613097025208, intercept=-0.9556877552963446, rvalue=0.9993798548422833, pvalue=0.0, stderr=0.0011193066215253792, intercept_stderr=0.0010041129200524142))
# Region(i=1, x0=0.77, x1=0.97, dx=0.19999999999999996, soln=LinregressResult(slope=1.8126986996486598, intercept=-0.9503592515167603, rvalue=0.9979297738768167, pvalue=0.0, stderr=0.0014993206695258676, intercept_stderr=0.001306783468663236))
# Region(i=1, x0=0.845, x1=0.93, dx=0.08500000000000008, soln=LinregressResult(slope=1.7942274506159812, intercept=-0.9342885905904642, rvalue=0.9992676418498668, pvalue=0.0, stderr=0.001342533561444965, intercept_stderr=0.00119062177269639))
# Region(i=1, x0=0.8675, x1=0.9575, dx=0.08999999999999997, soln=LinregressResult(slope=1.9739537811630032, intercept=-1.1017731383286196, rvalue=0.9991455484404511, pvalue=0.0, stderr=0.0015662079578144792, intercept_stderr=0.0014302388186938268))
# Region(i=0, x0=0.83, x1=0.94, dx=0.10999999999999999, soln=LinregressResult(slope=1.7792765356937041, intercept=-0.9223956976115302, rvalue=0.9994470513186002, pvalue=0.0, stderr=0.0010215054354223987, intercept_stderr=0.0009052324604219463))
# Region(i=4, x0=0.815, x1=0.9875, dx=0.1725000000000001, soln=LinregressResult(slope=1.9409412195484537, intercept=-1.0691192211186729, rvalue=0.9983670780241549, pvalue=0.0, stderr=0.0015409605100233806, intercept_stderr=0.0013911348897510984))
# Region(i=1, x0=0.84, x1=0.94, dx=0.09999999999999998, soln=LinregressResult(slope=1.797246018261412, intercept=-0.9399729356039837, rvalue=0.9994141658646948, pvalue=0.0, stderr=0.0011086243956189249, intercept_stderr=0.0009878014116669446))
# Region(i=1, x0=0.89, x1=0.98, dx=0.08999999999999997, soln=LinregressResult(slope=2.0764294669505667, intercept=-1.1994481870875235, rvalue=0.9987537130453329, pvalue=0.0, stderr=0.0019852129307675907, intercept_stderr=0.001857494295768687))
# Region(i=0, x0=0.8225, x1=0.965, dx=0.14249999999999996, soln=LinregressResult(slope=1.7859398032400229, intercept=-0.9340772070073529, rvalue=0.9994638956197437, pvalue=0.0, stderr=0.0008845894955038506, intercept_stderr=0.0007915304816853968))
# Region(i=1, x0=0.7975, x1=0.9625, dx=0.16500000000000004, soln=LinregressResult(slope=1.824283808738236, intercept=-0.9718225901184083, rvalue=0.9985761635200839, pvalue=0.0, stderr=0.0013778005909986966, intercept_stderr=0.001213386196038173))
# Region(i=1, x0=0.8525, x1=0.9625, dx=0.10999999999999999, soln=LinregressResult(slope=1.810839645658643, intercept=-0.9623858413245836, rvalue=0.9994452601404875, pvalue=0.0, stderr=0.0010383766094473142, intercept_stderr=0.0009424964135730398))
# Region(i=1, x0=0.7625, x1=0.915, dx=0.15250000000000008, soln=LinregressResult(slope=1.6481219090314572, intercept=-0.8266337895854086, rvalue=0.9990301487007986, pvalue=0.0, stderr=0.0010661551719113342, intercept_stderr=0.0008952183128030355))
# Region(i=0, x0=0.81, x1=0.955, dx=0.1449999999999999, soln=LinregressResult(slope=1.7405825118689948, intercept=-0.9024567877120553, rvalue=0.9993622373363635, pvalue=0.0, stderr=0.0009392088367239719, intercept_stderr=0.0008301013604256805))
# Region(i=1, x0=0.75, x1=0.9, dx=0.15000000000000002, soln=LinregressResult(slope=1.5940598481171853, intercept=-0.7846156519265975, rvalue=0.9990931538460931, pvalue=0.0, stderr=0.001006997855246331, intercept_stderr=0.0008316191060185634))
# Region(i=0, x0=0.8475, x1=0.915, dx=0.0675, soln=LinregressResult(slope=1.741345343152833, intercept=-0.9083544031534794, rvalue=0.9990045341473516, pvalue=0.0, stderr=0.0016788963090666458, intercept_stderr=0.0014795240066877988))
# Region(i=0, x0=0.76, x1=0.98, dx=0.21999999999999997, soln=LinregressResult(slope=1.7738957998506575, intercept=-0.9346339501242112, rvalue=0.9976356287472831, pvalue=0.0, stderr=0.0015002086451726114, intercept_stderr=0.0013083899093957732))
# Region(i=0, x0=0.8475, x1=0.9775, dx=0.13, soln=LinregressResult(slope=2.0297881826104134, intercept=-1.06732636637759, rvalue=0.9993404151192311, pvalue=0.0, stderr=0.0011641992167291154, intercept_stderr=0.0010628192836907966))
# Region(i=1, x0=0.765, x1=0.8975, dx=0.13249999999999995, soln=LinregressResult(slope=1.7918128721765318, intercept=-0.871248575760227, rvalue=0.9991865118868349, pvalue=0.0, stderr=0.0011366535158820479, intercept_stderr=0.0009452758636003977))
# Region(i=0, x0=0.7675, x1=0.95, dx=0.1825, soln=LinregressResult(slope=1.8600548861441595, intercept=-0.9200928007433644, rvalue=0.9990351543467687, pvalue=0.0, stderr=0.0010956113669501073, intercept_stderr=0.0009425402893457548))
# Region(i=0, x0=0.855, x1=0.965, dx=0.10999999999999999, soln=LinregressResult(slope=2.1250165268497447, intercept=-1.1646722062322703, rvalue=0.9989904477565057, pvalue=0.0, stderr=0.0016483008354983343, intercept_stderr=0.001500229398376747))
# Region(i=0, x0=0.83, x1=0.915, dx=0.08500000000000008, soln=LinregressResult(slope=1.9126459932564546, intercept=-0.9708226416551465, rvalue=0.9993621122543664, pvalue=0.0, stderr=0.0013317468792631132, intercept_stderr=0.0011630002695562397))
# Region(i=0, x0=0.78, x1=0.9625, dx=0.1825, soln=LinregressResult(slope=1.967300370690966, intercept=-1.0198176824382832, rvalue=0.9984899372602395, pvalue=0.0, stderr=0.0014603960868962438, intercept_stderr=0.0012744226564884188))
# Region(i=0, x0=0.79, x1=0.965, dx=0.17499999999999993, soln=LinregressResult(slope=1.930455285296832, intercept=-0.9770609499579727, rvalue=0.9991655892460082, pvalue=0.0, stderr=0.001081071703517123, intercept_stderr=0.0009501435150553055))
# Region(i=1, x0=0.7825, x1=0.95, dx=0.16749999999999998, soln=LinregressResult(slope=1.943739561558455, intercept=-0.9958255077105775, rvalue=0.9987849018909697, pvalue=0.0, stderr=0.001348811547412755, intercept_stderr=0.00117128537497188))
# Region(i=1, x0=0.6625, x1=0.91, dx=0.24750000000000005, soln=LinregressResult(slope=1.6422475681621158, intercept=-0.735780008024988, rvalue=0.9979336781156005, pvalue=0.0, stderr=0.001222085406869322, intercept_stderr=0.0009653289707675243))
# Region(i=1, x0=0.8575, x1=1.0, dx=0.14249999999999996, soln=LinregressResult(slope=2.196772883338396, intercept=-1.2261388974731116, rvalue=0.9990760121693033, pvalue=0.0, stderr=0.0014241641994449691, intercept_stderr=0.0013247699379237972))
# Region(i=0, x0=0.7525, x1=0.93, dx=0.1775000000000001, soln=LinregressResult(slope=1.815449872622067, intercept=-0.8825434893959229, rvalue=0.9991283506668232, pvalue=0.0, stderr=0.0010365123524051685, intercept_stderr=0.0008736321921907599))
# Region(i=1, x0=0.7275, x1=0.9575, dx=0.22999999999999998, soln=LinregressResult(slope=1.84082130856599, intercept=-0.9074393731662862, rvalue=0.9981377049249538, pvalue=0.0, stderr=0.0013543583228573224, intercept_stderr=0.0011449186533935825))
# Region(i=0, x0=0.835, x1=0.9775, dx=0.14250000000000007, soln=LinregressResult(slope=2.0058675963611963, intercept=-1.0521704147869613, rvalue=0.9994031139806648, pvalue=0.0, stderr=0.001052962277962806, intercept_stderr=0.0009557149028940897))
# Region(i=0, x0=0.7275, x1=0.9, dx=0.1725, soln=LinregressResult(slope=1.7394905248252541, intercept=-0.8280787141765714, rvalue=0.9989662718367196, pvalue=0.0, stderr=0.001099053985688668, intercept_stderr=0.0008962988239908569))
# Region(i=0, x0=0.755, x1=0.9325, dx=0.1775, soln=LinregressResult(slope=1.8108942451444567, intercept=-0.886981672841597, rvalue=0.9991760926358553, pvalue=0.0, stderr=0.0010051619357213087, intercept_stderr=0.0008496141356784031))
# Region(i=0, x0=0.77, x1=0.9275, dx=0.15749999999999997, soln=LinregressResult(slope=1.8426561676524655, intercept=-0.9198170607198343, rvalue=0.9990961585297499, pvalue=0.0, stderr=0.0011322725413344, intercept_stderr=0.0009618396317422032))
# Region(i=0, x0=0.7725, x1=0.9125, dx=0.14, soln=LinregressResult(slope=1.7943377889761187, intercept=-0.8800624155204276, rvalue=0.9992613898507751, pvalue=0.0, stderr=0.0010563460187961865, intercept_stderr=0.0008915816549713582))
# Region(i=0, x0=0.8375, x1=0.93, dx=0.09250000000000003, soln=LinregressResult(slope=1.9559490196944913, intercept=-1.0288782460489712, rvalue=0.9990501962662346, pvalue=0.0, stderr=0.0016150906610150088, intercept_stderr=0.0014281905367902973))
# Region(i=1, x0=0.7075, x1=1.0, dx=0.2925, soln=LinregressResult(slope=1.8195209927052605, intercept=-0.8958628969249518, rvalue=0.9978258924098192, pvalue=0.0, stderr=0.0012756673948165049, intercept_stderr=0.0010943941410282447))
# Region(i=0, x0=0.7625, x1=0.895, dx=0.13250000000000006, soln=LinregressResult(slope=1.7488671513308713, intercept=-0.8540306847198532, rvalue=0.9991747676844308, pvalue=0.0, stderr=0.0011147866781510648, intercept_stderr=0.0009251479126038412))
# Region(i=1, x0=0.8025, x1=0.9, dx=0.09750000000000003, soln=LinregressResult(slope=1.543437848137382, intercept=-0.8021164965729392, rvalue=0.9991816220146758, pvalue=0.0, stderr=0.0011519310073141616, intercept_stderr=0.000980792369448752))
# Region(i=0, x0=0.8425, x1=0.975, dx=0.13249999999999995, soln=LinregressResult(slope=1.808272072213368, intercept=-1.0415782853124003, rvalue=0.9980983329772987, pvalue=0.0, stderr=0.0017559285820884286, intercept_stderr=0.0015971780477374012))
# Region(i=0, x0=0.865, x1=0.985, dx=0.12, soln=LinregressResult(slope=1.7532785300472753, intercept=-0.9972893140318805, rvalue=0.9992597293019395, pvalue=0.0, stderr=0.0011187981150852563, intercept_stderr=0.0010355964289599146))
# Region(i=0, x0=0.87, x1=0.995, dx=0.125, soln=LinregressResult(slope=1.9426493900524322, intercept=-1.172248861600071, rvalue=0.9986839475998293, pvalue=0.0, stderr=0.001600999935902779, intercept_stderr=0.0014957295769608477))
# Region(i=1, x0=0.8625, x1=0.955, dx=0.09249999999999992, soln=LinregressResult(slope=1.6980579788452665, intercept=-0.9518917578630093, rvalue=0.9992604907634688, pvalue=0.0, stderr=0.0012337121980881725, intercept_stderr=0.0011215402754598245))
# Region(i=3, x0=0.815, x1=0.97, dx=0.15500000000000003, soln=LinregressResult(slope=1.7262620754463471, intercept=-0.9773887107986444, rvalue=0.9979755046614003, pvalue=0.0, stderr=0.0016017966464028188, intercept_stderr=0.0014313731578285659))
# Region(i=0, x0=0.7975, x1=0.9525, dx=0.15500000000000003, soln=LinregressResult(slope=1.5928256106795378, intercept=-0.8616685648757736, rvalue=0.9990586566973535, pvalue=0.0, stderr=0.0010102213746577813, intercept_stderr=0.0008849165431583705))
# Region(i=1, x0=0.8275, x1=0.9575, dx=0.13, soln=LinregressResult(slope=1.711313247798552, intercept=-0.9712866450973681, rvalue=0.9983772890675536, pvalue=0.0, stderr=0.0015544643070336845, intercept_stderr=0.0013877009902519201))
# Region(i=16, x0=0.835, x1=1.0, dx=0.16500000000000004, soln=LinregressResult(slope=1.7248046167725588, intercept=-0.9841516773896783, rvalue=0.9991327893273837, pvalue=0.0, stderr=0.0010014099338694266, intercept_stderr=0.0009227085937429086))
# Region(i=13, x0=0.8375, x1=0.98, dx=0.14249999999999996, soln=LinregressResult(slope=1.8034811033291778, intercept=-1.0569698768738118, rvalue=0.9981099260787584, pvalue=0.0, stderr=0.001695723023526057, intercept_stderr=0.0015430720438202666))
# Region(i=0, x0=0.8275, x1=0.9625, dx=0.135, soln=LinregressResult(slope=1.6445071235087607, intercept=-0.915696799719679, rvalue=0.9992346714054064, pvalue=0.0, stderr=0.0010025763467247752, intercept_stderr=0.0008989933809142494))
# Region(i=1, x0=0.835, x1=0.97, dx=0.135, soln=LinregressResult(slope=1.7594621701552045, intercept=-1.0204280363713796, rvalue=0.9982387498774961, pvalue=0.0, stderr=0.001637806641745199, intercept_stderr=0.0014812156231354353))
# Region(i=1, x0=0.82, x1=0.9575, dx=0.13750000000000007, soln=LinregressResult(slope=1.618841461617903, intercept=-0.8962323415942638, rvalue=0.9991234313146383, pvalue=0.0, stderr=0.001048706653077337, intercept_stderr=0.0009323335328670616))
# Region(i=0, x0=0.825, x1=0.9575, dx=0.13250000000000006, soln=LinregressResult(slope=1.6858815558772549, intercept=-0.9578597669380655, rvalue=0.9983757989599963, pvalue=0.0, stderr=0.0015178909493161845, intercept_stderr=0.0013529449742361124))
# Region(i=0, x0=0.77, x1=0.935, dx=0.16500000000000004, soln=LinregressResult(slope=1.5067343693088067, intercept=-0.7989201805244084, rvalue=0.9987500238561411, pvalue=0.0, stderr=0.0010631213421141068, intercept_stderr=0.0009081349502009708))
# Region(i=0, x0=0.855, x1=0.955, dx=0.09999999999999998, soln=LinregressResult(slope=1.7555250609995505, intercept=-1.022765777626784, rvalue=0.998464498811504, pvalue=0.0, stderr=0.0017656179157973725, intercept_stderr=0.0015977938672635703))
# Region(i=1, x0=0.6825, x1=0.9325, dx=0.25, soln=LinregressResult(slope=1.3696446128778057, intercept=-0.6815010021968548, rvalue=0.9974949882308611, pvalue=0.0, stderr=0.0011161937931129034, intercept_stderr=0.0009044638731463493))
# Region(i=0, x0=0.835, x1=0.9425, dx=0.10750000000000004, soln=LinregressResult(slope=1.6804259035732085, intercept=-0.9564781113342602, rvalue=0.9987133769462528, pvalue=0.0, stderr=0.0014946422147372746, intercept_stderr=0.0013308862098281207))
# Region(i=1, x0=0.895, x1=0.985, dx=0.08999999999999997, soln=LinregressResult(slope=1.7761228670853528, intercept=-1.0441662160840197, rvalue=0.9992645238397927, pvalue=0.0, stderr=0.0012992351198757826, intercept_stderr=0.001221402703578098))
# Region(i=0, x0=0.845, x1=0.995, dx=0.15000000000000002, soln=LinregressResult(slope=1.8377546969382375, intercept=-1.0963467533319653, rvalue=0.9981943551200778, pvalue=0.0, stderr=0.0016262921038672504, intercept_stderr=0.001499813673877042))
# Number of successful runs: 120 (100 %)

# %%
# Process solutions
x_t, y_t = ureg.parse_expression(str(data[0].df.dtypes.iloc[1])[5:-1]), ureg.parse_expression(str(data[0].df.dtypes.iloc[0])[5:-1])
X0, X1, slopes, icepts = zip(*[(soln.x0, soln.x1, soln.soln.slope, soln.soln.intercept) for soln in solns])
x0_mu, x1_mu, slope_mu, slope_se, icept_mu, icept_se = np.mean(X0), np.mean(X1), np.mean(slopes), np.std(slopes), np.mean(icepts), np.std(icepts)

# Plot data
fig, ax = plt.subplots()
for dat in data:
    dat.dfdq.plot.scatter('Distance', 'Force', s=0.001, c='darkgrey', ax=ax)
ax.plot(*region_line(x0_mu, x1_mu, slope_mu, icept_mu), c='red')
ax.fill_between([x0_mu, x1_mu], region_line(x0_mu, x1_mu, slope_mu-slope_se, icept_mu)[1], region_line(x0_mu, x1_mu, slope_mu+slope_se, icept_mu)[1], facecolor='red', alpha=0.3)

# Get flexural modulus
slope = slope_mu * y_t / x_t
const = (1/16) * (20*ureg.mm)**3 / ((100*ureg.um) * (129*ureg.um)**3)
E = (slope * const).to(ureg.GPa)
print(E)
# Out:
# 4004.8540938200254 gigapascal
